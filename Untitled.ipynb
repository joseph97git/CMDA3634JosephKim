# %%
from matplotlib import pyplot as plt

# %%
y = [48.3911, 30.3909, 21.1846, 16.1705, 13.0746, 10.9482, 9.43861, 8.26788, 7.38102, 6.64935, 6.05635, 5.55988, 5.13626, 4.77082, 4.4654, 4.17143]

# %%
x = list(range(1,17))

# %%
# %matplotlib inline
plt.plot(x,y)
plt.xticks(list(range(1,17,1)))
plt.yticks(list(range(0,51,5)))
plt.xlabel('Number of OpenMP Threads')
plt.ylabel('Time in Seconds')
plt.title('Time to Run Mandelbrot vs Number of OpenMP Threads')

plt.savefig('mandelbrot_speedup_plot.png')
